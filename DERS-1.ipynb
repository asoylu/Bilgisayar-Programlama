# %% [markdown]
# **Bilgisayar Programlama Dersi-1 4 Ekim 2022 @Nigde by A. Soylu**

# %% [markdown]
# **Hesap** **makinası**

# %%
2+2 #4 işlem işlemi yapar(yorum satırı)
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
3**0.5
# Out:
# 1.7320508075688772

# %%
2*(10+5)
# Out:
# 30

# %%
float(15)/6
# Out:
# 2.5

# %%
x=2.5
y=5.5
m=(x+y)/2
print ('x=',x,'y=',y,'sonuc=',m)
# Out:
# x= 2.5 y= 5.5 sonuc= 4.0

# %%
import math
print(math.sin(30))
print(math.exp(1.0))
# Out:
# -0.9880316240928618
# 2.718281828459045

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.log(math.e)
# Out:
# 1.0

# %%
x=0.5
x*3
x=0.7
x*3
# Out:
# 2.0999999999999996

# %%
tax=12.5/100
price=100.50
price*tax
price+_
# Out:
# 113.0625

# %%
x=4
x=x+1 # x+=1 şeklinde kullanılabilir
print(x)
# Out:
# 5

# %%
x=4
x+=1
print(x)
# Out:
# 5

# %% [markdown]
# **Veriler** ve **Tipleri**

# %%
a=45.0
type(a)
# Out:
# float

# %%
b='This is a string'
type(b)
# Out:
# str

# %%
c=2+1j
type(c)
# Out:
# complex

# %%
d=[1,3,56]
type(d)
# Out:
# list

# %%
a="34"
b=int(a)
type(b)
# Out:
# int

# %%
c=75555.8888555
d=str(c)
type(d)
# Out:
# str

# %%
round(7.159)
# Out:
# 7

# %%
a='35.342'
type(a)
b=float(a)
type(b)
# Out:
# float

# %%
x=1+3j
print(x)
# Out:
# (1+3j)

# %%
x.imag
# Out:
# 3.0

# %%
x.real
# Out:
# 1.0

# %%
x.conjugate
# Out:
# <function complex.conjugate>

# %%
print(x.conjugate)
# Out:
# <built-in method conjugate of complex object at 0x7fda5cfa29d0>

# %%
a=4.8999
math.sqrt(a)
# Out:
# 2.2135717743050485

# %%
v=-56.9999
abs(v)
# Out:
# 56.9999

# %% [markdown]
# **String Dizi**

# %%
a='Merhaba Dunya'
print(a)
# Out:
# Merhaba Dunya

# %%
len(a)
# Out:
# 13

# %%
'merhaba '+'dunya'
# Out:
# 'merhaba dunya'

# %%
a='bu ornek bir cumledir'
a.upper()
# Out:
# 'BU ORNEK BIR CUMLEDIR'

# %%
a.split()
# Out:
# ['bu', 'ornek', 'bir', 'cumledir']

# %%
a='The dog is hungry. The cat is bored. The snake is awake'

# %%
a.split()
# Out:
# ['The',
#  'dog',
#  'is',
#  'hungry.',
#  'The',
#  'cat',
#  'is',
#  'bored.',
#  'The',
#  'snake',
#  'is',
#  'awake']

# %%
a.split('.')
# Out:
# ['The dog is hungry', ' The cat is bored', ' The snake is awake']

# %%
s=a.split('.')
'.'.join(s)
' STOP'.join(s)
# Out:
# 'The dog is hungry STOP The cat is bored STOP The snake is awake'

# %% [markdown]
# List

# %%
a=[34,12,54,'dog','cat']
len(a)
# Out:
# 5

# %%
[3,4,1]+[34,35,400]
# Out:
# [3, 4, 1, 34, 35, 400]

# %%
a=[3,4,1]
a.append(8)
print(a)
# Out:
# [3, 4, 1, 8]

# %%
a.remove(3)

# %%
print(a)
# Out:
# [4, 1]

# %%
print(range(8))
# Out:
# range(0, 8)

# %%
range(3,100,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-9b78b0efa27c> in <module>
# ----> 1 arange(3,100,5)
#
# NameError: name 'arange' is not defined

# %%
import numpy as np
np.arange(10)
np.arange(3,100,5)
# Out:
# array([ 3,  8, 13, 18, 23, 28, 33, 38, 43, 48, 53, 58, 63, 68, 73, 78, 83,
#        88, 93, 98])

# %%
for i in range(11):
  print(i,i**2)
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 10 100

# %% [markdown]
# **Demet**

# %%
a=(12,13,'dog')
type(a)
# Out:
# tuple

# %%
a[0]
# Out:
# 12

# %%
t=(42,)

# %%
typr(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-9ab54df736fe> in <module>
# ----> 1 typr(t)
#
# NameError: name 'typr' is not defined

# %%
len(t)
# Out:
# 1

# %% [markdown]
# Dizileri **İndeksleme**

# %%
a=['dog','cat','mouse']
a[0]
# Out:
# 'dog'

# %%
a[1]
# Out:
# 'cat'

# %%
a[2]
# Out:
# 'mouse'

# %%
a[-1]
# Out:
# 'mouse'

# %%
a[-2]
# Out:
# 'cat'

# %%
b='hello world!'
b[0]
# Out:
# 'h'

# %%
b[0:3]
# Out:
# 'hel'

# %%
b[1:4]
# Out:
# 'ell'

# %%
b[0:6]
# Out:
# 'hello '

# %%
b[0:-1]
# Out:
# 'hello world'

# %%
b[:5]
# Out:
# 'hello'

# %%
b[:]
# Out:
# 'hello world!'

# %%
d={}
type(d)
# Out:
# dict

# %%
d2={2:4,3:9,4:16,5:25}

# %%
d2
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25}

# %%
order={}
order['Peter']='Pint of bitter'
order['Paul']='Half bint of H'
order['Mary']='Gin'
for person in order.keys():
  print(person,'request',order[person])
# Out:
# Peter request Pint of bitter
# Paul request Half bint of H
# Mary request Gin

# %%
a=range(10)

# %%
print(a)
# Out:
# range(0, 10)

# %%
id(a)
# Out:
# 140575838046176

# %%
a=5
b=1
type(a)
type(b)
# Out:
# int

# %%
a==b
# Out:
# False

# %%
x=6
y=5
x is y
# Out:
# False

# %%
8/3
# Out:
# 2.6666666666666665

# %%
8//3 #Mod bulma
# Out:
# 2

# %%
8%3 #Mod bulma
# Out:
# 2

# %%
1_sabit=8
# Out:
#   File "<ipython-input-133-b0f5cb47df59>", line 1
#     1_sabit=8
#      ^
# SyntaxError: invalid token

# %%
sabit_1=8

# %%
isikHizi=3*10**8

# %%
a='100'
b='200'
print(a+b)
# Out:
# 100200

# %%
a=input('ilk sayiyi giriniz=')
b=input('ikinci sayiyi giriniz=')
toplam=int(a)+int(b)
print('Toplam=',toplam)
# Out:
# ilk sayiyi giriniz=52
# ikinci sayiyi giriniz=56
# Toplam= 108

# %%
radius=float(input('yaricapi giriniz='))
pi=3.14
alan=pi*(radius**2)
cevre=2*pi*radius
print('alan=',alan)
print('cevre=',cevre)
# Out:
# yaricapi giriniz=2.2
# alan= 15.197600000000003
# cevre= 13.816000000000003

# %%
name='Asim'
surname='Soylu'
age='42'
print('May name is '+''+ name +' '+surname+' '+ 'I am' + age+'years old')
# Out:
# May name is Asim Soylu I am42years old

# %%
name='Emir'
print('My name is {}'.format(name))
# Out:
# My name is Emir

# %%
sonuc=float(300/1000)
print('Sonuc= {}'.format(sonuc))
# Out:
# Sonuc= 0.3

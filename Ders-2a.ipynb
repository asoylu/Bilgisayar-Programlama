# %% [markdown]
# **Ders-2 11 Ekim 2022 A. Soylu**

# %%
a,b,c=2,3,5
print(a,b,c)
# Out:
# 2 3 5

# %%
a=2
b=3
c=5
print(a,b,c)
# Out:
# 2 3 5

# %%
x,y,z=2,5,10
a=float(input('1.sayı girin='))
b=float(input('2.sayı girin='))
sonuc=(a*b)-(x+y+z)
print(x,y,z,a,b,'sonuc=',sonuc)
# Out:
# 1.sayı girin=12
# 2.sayı girin=24
# 2 5 10 12.0 24.0 sonuc= 271.0

# %%
a,b,c,d=8,5,10,4
result=(a==b)
print(result)
# Out:
# False

# %%
username=input('username giriniz=')
password=input('password giriniz=')

result=('asimsoylu'==username) and ('12345'==password)
print(result)
# Out:
# username giriniz=asimsoylu
# password giriniz=45678
# False

# %%
a=int(input('a='))
b=int(input('b='))
result=(a>=b)
print(f'a:{a},b:{b} den büyüktür={result}')
# Out:
# a=120
# b=120
# a:120,b:120 den büyüktür=True

# %%
vize1=float(input('1.vize giriniz='))
vize2=float(input('2.vize giriniz='))
final=float(input('final giriniz='))
sonuc=(((vize1+vize2)/2.0)*0.4)+(final*0.6)
print(f'not:{sonuc} ve dersten geçme durumu:{sonuc>=50}')
# Out:
# 1.vize giriniz=15
# 2.vize giriniz=20
# final giriniz=80
# not:55.0 ve dersten geçme durumu:True

# %%
x=4
(x>=5) and (x<10)
# Out:
# False

# %%
hak=2
devam='e'
(hak>0) or (devam=='e')
# Out:
# True

# %%
name=input('adınız=')
kg=float(input('kilonuz='))
hg=float(input('boyunuz='))
index=kg/(hg**2)
